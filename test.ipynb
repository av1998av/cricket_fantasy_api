# %%
import requests

# %%
res = requests.get('https://icc.dream11.com/icc-season/services/feed/player/stats', headers = {'Content-Type': 'application/json',
      'User-Agent': 'Mozilla/5.0',
      'Accept': '*/*',
      'Connection': 'keep-alive',
      'Accept-Encoding': 'gzip, deflate, br',
      'Sec-Fetch-Mode': 'cors',
      'Access-Control-Allow-Origin': '*'})

# %%
print(res.json()['Data']['Value']['PlayerStats'])
# Out:
# [{'plyrid': 3632, 'teamid': '4', 'isfp': '0', 'isusrplyr': None, 'isinjd': '0', 'isuncap': 0, 'plyrnm': 'Dinesh Karthik', 'plyrshrtnm': 'Dinesh Karthik', 'value': '8', 'desc': 'Right Handed', 'isanned': '', 'profileurl': '', 'tmnm': 'India', 'tmshrtnm': 'IND', 'sklid': 4, 'sklnm': 'WICKET KEEPER', 'sklshrtnm': 'WK', 'IsActive': 1, 'ovrpoint': '45', 'pstats': [{'gid': '1', 'sper': '4.19', 'gdpoint': '-', 'csper': '0.08', 'vcsper': '0.06'}, {'gid': '2', 'sper': '4.06', 'gdpoint': '-', 'csper': '0.08', 'vcsper': '0.07'}, {'gid': '3', 'sper': '4.11', 'gdpoint': '-', 'csper': '0.09', 'vcsper': '0.07'}, {'gid': '4', 'sper': '6.35', 'gdpoint': '21', 'csper': '0.1', 'vcsper': '0.1'}, {'gid': '5', 'sper': '5.4', 'gdpoint': '-', 'csper': '0.1', 'vcsper': '0.08'}, {'gid': '6', 'sper': '5.05', 'gdpoint': '-', 'csper': '0.1', 'vcsper': '0.08'}, {'gid': '7', 'sper': '4.64', 'gdpoint': '-', 'csper': '0.1', 'vcsper': '0.08'}, {'gid': '8', 'sper': '4.52', 'gdpoint': '-', 'csper': '0.1', 'vcsper': '0.
# ...
